# %%
import numpy as np
import pandas as pd
import psycopg2
import getpass
# for configuring connection 
from configobj import ConfigObj
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from utils import *

# %%
# Create a database connection using settings from config file
config='../db/config.ini'

# connection info
conn_info = dict()
if os.path.isfile(config):
    config = ConfigObj(config)
    conn_info["sqluser"] = config['username']
    conn_info["sqlpass"] = config['password']
    conn_info["sqlhost"] = config['host']
    conn_info["sqlport"] = config['port']
    conn_info["dbname"] = config['dbname']
    conn_info["schema_name"] = config['schema_name']
else:
    conn_info["sqluser"] = 'postgres'
    conn_info["sqlpass"] = ''
    conn_info["sqlhost"] = '192.168.60.144'
    conn_info["sqlport"] = 6432
    conn_info["dbname"] = 'eicu'
    conn_info["schema_name"] = 'public,eicu_crd'
    
# Connect to the eICU database
print('Database: {}'.format(conn_info['dbname']))
print('Username: {}'.format(conn_info["sqluser"]))
if conn_info["sqlpass"] == '':
    # try connecting without password, i.e. peer or OS authentication
    try:
        if (conn_info["sqlhost"] == '192.168.60.144') & (conn_info["sqlport"]=='6432'):
            con = psycopg2.connect(dbname=conn_info["dbname"],
                                   user=conn_info["sqluser"])            
        else:
            con = psycopg2.connect(dbname=conn_info["dbname"],
                                   host=conn_info["sqlhost"],
                                   port=conn_info["sqlport"],
                                   user=conn_info["sqluser"])
    except:
        conn_info["sqlpass"] = getpass.getpass('Password: ')

        con = psycopg2.connect(dbname=conn_info["dbname"],
                               host=conn_info["sqlhost"],
                               port=conn_info["sqlport"],
                               user=conn_info["sqluser"],
                               password=conn_info["sqlpass"])
query_schema = 'set search_path to ' + conn_info['schema_name'] + ';'
# Out:
# Database: eicu
# Username: postgres

# %%
from sqlalchemy import create_engine,text

con = create_engine(
    f'postgresql://{conn_info["sqluser"]}:{conn_info["sqlpass"]}@{conn_info["sqlhost"]}:{conn_info["sqlport"]}/{conn_info["dbname"]}',
    connect_args={'options': '-c search_path=eicu_crd'}
)

# %%
create_table_query = query_schema + """
drop materialized view if exists diagnoses cascade;
create materialized view diagnoses as
  -- for past medical history:
select l.patient,l.apacheadmissiondx, ph.pasthistorypath as diagnosisstring
from pasthistory as ph
inner join labels as l on l.patient = ph.patientunitstayid
where ph.pasthistoryoffset > 0
      and ph.pasthistorypath LIKE '%Organ Systems%'      
"""
with con.begin() as connection:
    connection.execute(text(create_table_query)) 
    
select_query = "SELECT * FROM diagnoses;"
df_dx = pd.read_sql_query(select_query, con)
print("there are {} patiets and {} records".format(df_dx["patient"].nunique(),df_dx["patient"].count()))
# Out:
# there are 93272 patiets and 482385 records

# %% [markdown]
# ## process the diagnosis

# %%
flat =df_dx[['patient','apacheadmissiondx']].drop_duplicates()
diagnoses = df_dx.copy()

# %%
diagnoses
# Out:
#         patient                              apacheadmissiondx  \
# 0        141168  Rhythm disturbance (atrial, supraventricular)
# 1        141168  Rhythm disturbance (atrial, supraventricular)
# 2        141168  Rhythm disturbance (atrial, supraventricular)
# 3        141168  Rhythm disturbance (atrial, supraventricular)
# 4        141168  Rhythm disturbance (atrial, supraventricular)
# ...         ...                                            ...
# 482380  3353226                             Effusions, pleural
# 482381  3353226                             Effusions, pleural
# 482382  3353237                             Embolus, pulmonary
# 482383  3353254                             Bleeding, lower GI
# 482384  3353254                             Bleeding, lower GI
#
#                                           diagnosisstring
# 0       notes/Progress Notes/Past History/Organ System...
# 1       notes/Progress Notes/Past History/Organ System...
# 2       notes/Progress Notes/Past History/Organ System...
# 3       notes/Progress Notes/Past History/Organ System...
# 4       notes/Progress Notes/Past History/Organ System...
# ...                                                   ...
# 482380  notes/Progress Notes/Past History/Organ System...
# 482381  notes/Progress Notes/Past History/Organ System...
# 482382  notes/Progress Notes/Past History/Organ System...
# 482383  notes/Progress Notes/Past History/Organ System...
# 482384  notes/Progress Notes/Past History/Organ System...
#
# [482385 rows x 3 columns]

# %%
query = query_schema + """
select distinct(patient)
from id
order by patient;
"""
id = pd.read_sql_query(query, con)

# %%
common_patients = set( diagnoses['patient'])& set(id['patient'])
diagnoses = diagnoses[diagnoses['patient'].isin(common_patients)]
print("there are {} patiets and {} records".format(diagnoses["patient"].nunique(),diagnoses["patient"].count()))
# Out:
# there are 3072 patiets and 24416 records

# %%
diagnoses=diagnoses.drop(columns=['apacheadmissiondx'])
diagnoses
# Out:
#         patient                                    diagnosisstring
# 23819    260132  notes/Progress Notes/Past History/Organ System...
# 24064    261021  notes/Progress Notes/Past History/Organ System...
# 24065    261021  notes/Progress Notes/Past History/Organ System...
# 24066    261021  notes/Progress Notes/Past History/Organ System...
# 24067    261021  notes/Progress Notes/Past History/Organ System...
# ...         ...                                                ...
# 471271  3247116  notes/Progress Notes/Past History/Organ System...
# 471272  3247116  notes/Progress Notes/Past History/Organ System...
# 471273  3247116  notes/Progress Notes/Past History/Organ System...
# 471274  3247116  notes/Progress Notes/Past History/Organ System...
# 471275  3247116  notes/Progress Notes/Past History/Organ System...
#
# [24416 rows x 2 columns]

# %%
df1 = diagnoses.copy()
df1['diagnosisstring'] = df1['diagnosisstring'].str.replace('notes/Progress Notes/Past History/Organ Systems/', ' ')
df1['diagnosisstring'] = df1['diagnosisstring'].str.replace('|', '/')
split = df1['diagnosisstring'].str.split('/')
df1['first'] = split.str[0]
df1['second'] = split.str[1]
df1['third'] = split.str[2]
df1['fourth'] = split.str[3]
df1
# Out:
#         patient                                    diagnosisstring  \
# 23819    260132        Endocrine (R)/Hypothyroidism/hypothyroidism
# 24064    261021         Cardiovascular (R)/Pacemaker/unknown pacer
# 24065    261021                            Pulmonary/Asthma/asthma
# 24066    261021                    Pulmonary/COPD/COPD  - moderate
# 24067    261021                            Pulmonary/Asthma/asthma
# ...         ...                                                ...
# 471271  3247116   Pulmonary/Respiratory Failure/respiratory fai...
# 471272  3247116   Cardiovascular (R)/Hypertension Requiring Tre...
# 471273  3247116                  Pulmonary/Home Oxygen/home oxygen
# 471274  3247116                      Pulmonary/COPD/COPD  - severe
# 471275  3247116   Cardiovascular (R)/Arrhythmias/atrial fibrill...
#
#                       first                            second  \
# 23819         Endocrine (R)                    Hypothyroidism
# 24064    Cardiovascular (R)                         Pacemaker
# 24065             Pulmonary                            Asthma
# 24066             Pulmonary                              COPD
# 24067             Pulmonary                            Asthma
# ...                     ...                               ...
# 471271            Pulmonary               Respiratory Failure
# 471272   Cardiovascular (R)  Hypertension Requiring Treatment
# 471273            Pulmonary                       Home Oxygen
# 471274            Pulmonary                              COPD
# 471275   Cardiovascular (R)                       Arrhythmias
#
#                                        third fourth
# 23819                         hypothyroidism    NaN
# 24064                          unknown pacer    NaN
# 24065                                 asthma    NaN
# 24066                       COPD  - moderate    NaN
# 24067                                 asthma    NaN
# ...                                      ...    ...
# 471271  respiratory failure - within 5 years    NaN
# 471272      hypertension requiring treatment    NaN
# 471273                           home oxygen    NaN
# 471274                        COPD  - severe    NaN
# 471275         atrial fibrillation - chronic    NaN
#
# [24416 rows x 6 columns]

# %%
frequency1 = pd.DataFrame()
frequency1['noAnnotations'] = df1['first'].value_counts() 
frequency1['%'] = df1['first'].value_counts() / len(df1.index) * 100
frequency1
# Out:
#                         noAnnotations          %
# first
# Cardiovascular (R)              12341  50.544725
# Endocrine (R)                    3258  13.343709
# Pulmonary                        2310   9.461009
# Neurologic                       1807   7.400885
# Hematology                       1803   7.384502
# Renal  (R)                       1350   5.529161
# Gastrointestinal (R)             1232   5.045872
# Rheumatic                         165   0.675786
# Infectious Disease (R)            150   0.614351

# %%
frequency2 = pd.DataFrame()
frequency2['noAnnotations'] = df1['second'].value_counts() 
frequency2['%'] = df1['second'].value_counts() / len(df1.index) * 100
frequency2
# Out:
#                                         noAnnotations          %
# second
# Hypertension Requiring Treatment                 4771  19.540465
# Oncology (R)                                     1803   7.384502
# Congestive Heart Failure                         1341   5.492300
# Non-Insulin Dependent Diabetes                   1325   5.426769
# Arrhythmias                                      1241   5.082733
# COPD                                             1152   4.718218
# Insulin Dependent Diabetes                       1010   4.136632
# Cirrhosis                                         920   3.768021
# Valve disease                                     908   3.718873
# Myocardial Infarction                             894   3.661533
# Hypothyroidism                                    821   3.362549
# Strokes                                           782   3.202818
# Procedural Coronary Intervention                  739   3.026704
# Renal Insufficiency                               701   2.871068
# Coronary Artery Bypass                            580   2.375491
# Asthma                                            570   2.334535
# Peripheral Vascular Disease                       540   2.211664
# Seizures                                          482   1.974115
# Renal Failure                                     461   1.888106
# Pacemaker                                         336   1.376147
# Venous Thrombosis                                 278   1.138598
# Home Oxygen                                       266   1.089450
# Dementia                                          254   1.040301
# Pulmonary Function Tests                          238   0.974771
# Peptic Ulcer Disease                              233   0.954292
# TIA(s)                                            222   0.909240
# Angina                                            215   0.880570
# AICD                                              203   0.831422
# Pulmonary Embolism                                179   0.733126
# s                                                 179   0.733126
# Rheumatoid Arthritis                              108   0.442333
# Chronic Stone Disease                              92   0.376802
# HIV (only)                                         77   0.315367
# Exercise Tolerance                                 76   0.311271
# Immunosuppression within past 6 months             69   0.282602
# Hyperthyroidism                                    48   0.196592
# Recent Steroid Use (for > 10 days)                 48   0.196592
# SLE                                                43   0.176114
# Restrictive Disease                                43   0.176114
# Neuromuscular Disease                              37   0.151540
# Respiratory Failure                                37   0.151540
# Intracranial Mass                                  30   0.122870
# Hypersplenism                                      29   0.118775
# Dermato                                            13   0.053244
# Neurogenic Bladder                                  9   0.036861
# Cushing's Syndrome                                  5   0.020478
# AIDS                                                4   0.016383
# Sarcoidosis                                         2   0.008191
# Hypercalcemia                                       1   0.004096
# Scleroderma                                         1   0.004096

# %%
from bigtree import Node, list_to_tree, tree_to_dot, dataframe_to_tree, tree_to_pillow

for disease in frequency1.index.get_level_values('first'):
    df_ = df1[df1['first'] == disease]
    df_.set_index(['patient'], inplace = True)
    
    paths_mult_ = df_.groupby('diagnosisstring', dropna = True)['diagnosisstring'].size().to_frame('noAnnotations')
    paths_mult_.reset_index(inplace=True)
    paths_mult_.sort_values('noAnnotations', ascending = False, inplace = True)

    paths_ = list(pd.unique(df_['diagnosisstring']))
    root_ = dataframe_to_tree(paths_mult_, sep = '/')
    root_.show(attr_list=["noAnnotations"])
    pillow_image_ = tree_to_pillow(root_)
# Out:
#  Cardiovascular (R)
# ├── Hypertension Requiring Treatment
# │   └── hypertension requiring treatment [noAnnotations=4771]
# ├── Congestive Heart Failure
# │   ├── CHF [noAnnotations=962]
# │   ├── CHF - severity unknown [noAnnotations=151]
# │   ├── CHF - class II [noAnnotations=104]
# │   ├── CHF - class III [noAnnotations=86]
# │   ├── CHF - class IV [noAnnotations=29]
# │   └── CHF - class I [noAnnotations=9]
# ├── Arrhythmias
# │   ├── atrial fibrillation - chronic [noAnnotations=857]
# │   ├── atrial fibrillation - intermittent [noAnnotations=221]
# │   ├── ventricular tachycardia [noAnnotations=85]
# │   ├── SVT- other [noAnnotations=27]
# │   ├── sick sinus syndrome [noAnnotations=23]
# │   ├── ventricular ectopy [noAnnotations=22]
# │   ├── ventricular fibrillation [noAnnotations=5]
# │   └── MAT [noAnnotations=1]
# ├── Peripheral Vascular Disease
# │   └── peripheral vascular disease [noAnnotations=540]
# ├── Myocardial Infarction
# │   ├── MI - date unknown [noAnnotations=420]
# │   ├── MI - remote [noAnnotations=196]
# │   ├── MI - within 6 months [noAnnotations=119]
# │   ├── MI - within 5 years [noAnnotations=69]
# │   ├── multiple
# │   │   └── multiple [noAnnotations=56]
# │   └── MI - within 2 years [noAnnotations=34]
# ├── Procedural Coronary Intervention
# │   ├── procedural coronary intervention - date unknown [noAnnotations=337]
# │   ├── procedural coronary intervention - remote [noAnnotations=171]
# │   ├── procedural coronary intervention - within 5 years [noAnnotations=81]
# │   ├── procedural coronary intervention - within 6 months [noAnnotations=74]
# │   ├── multiple
# │   │   └── multiple [noAnnotations=43]
# │   └── procedural coronary intervention - within 2 years [noAnnotations=33]
# ├── Valve disease
# │   ├── AS [noAnnotations=255]
# │   ├── MR [noAnnotations=219]
# │   ├── s
# │   │   ├── p AVR [noAnnotations=178]
# │   │   ├── p MVR [noAnnotations=90]
# │   │   └── p TVR [noAnnotations=17]
# │   ├── TR [noAnnotations=54]
# │   ├── MS [noAnnotations=49]
# │   └── AR [noAnnotations=46]
# ├── Coronary Artery Bypass
# │   ├── CABG - date unknown [noAnnotations=242]
# │   ├── CABG - remote [noAnnotations=217]
# │   ├── multiple
# │   │   └── multiple [noAnnotations=42]
# │   ├── CABG - within 5 years [noAnnotations=42]
# │   ├── CABG - within 6 months [noAnnotations=19]
# │   └── CABG - within 2 years [noAnnotations=18]
# ├── AICD
# │   └── AICD [noAnnotations=203]
# ├── Angina
# │   ├── angina [noAnnotations=183]
# │   ├── angina - class I [noAnnotations=11]
# │   ├── angina - severity unknown [noAnnotations=8]
# │   ├── angina - class III [noAnnotations=6]
# │   ├── angina - class II [noAnnotations=4]
# │   └── angina - class IV [noAnnotations=3]
# ├── Pacemaker
# │   ├── unknown pacer [noAnnotations=172]
# │   ├── V paced [noAnnotations=93]
# │   ├── A
# │   │   └── V paced [noAnnotations=63]
# │   └── A paced [noAnnotations=8]
# ├── Venous Thrombosis
# │   ├── DVT - date unknown [noAnnotations=138]
# │   ├── DVT - remote [noAnnotations=68]
# │   ├── DVT - within 6 months [noAnnotations=38]
# │   ├── DVT - within 2 years [noAnnotations=17]
# │   ├── multiple
# │   │   └── multiple [noAnnotations=10]
# │   └── DVT - within 5 years [noAnnotations=7]
# ├── Pulmonary Embolism
# │   ├── pulmonary embolism - date unknown [noAnnotations=57]
# │   ├── pulmonary embolism - remote [noAnnotations=46]
# │   ├── pulmonary embolism - within 6 months [noAnnotations=40]
# │   ├── pulmonary embolism - within 2 years [noAnnotations=22]
# │   ├── pulmonary embolism - within 5 years [noAnnotations=12]
# │   └── multiple
# │       └── multiple [noAnnotations=2]
# ├── Exercise Tolerance
# │   ├── limited - household activities (1-4 mets) [noAnnotations=41]
# │   ├── moderate - stairs
# │   │   └── brisk walking (5-10 mets) [noAnnotations=24]
# │   ├── unknown [noAnnotations=8]
# │   ├── excellent - strenuous exercise (>10 mets) [noAnnotations=2]
# │   └── none - bed-ridden [noAnnotations=1]
# └── s
#     └── p Heart Transplant
#         └── s
#             └── p heart transplant [noAnnotations=40]
#  Endocrine (R)
# ├── Non-Insulin Dependent Diabetes
# │   ├── medication dependent [noAnnotations=1047]
# │   └── non-medication dependent [noAnnotations=278]
# ├── Insulin Dependent Diabetes
# │   └── insulin dependent diabetes [noAnnotations=1010]
# ├── Hypothyroidism
# │   └── hypothyroidism [noAnnotations=821]
# ├── Hyperthyroidism
# │   └── hyperthyroidism [noAnnotations=48]
# ├── Recent Steroid Use (for > 10 days)
# │   └── recent steroid use for > 10 days [noAnnotations=48]
# ├── Cushing's Syndrome
# │   └── Cushing's syndrome [noAnnotations=5]
# └── Hypercalcemia
#     └── hypercalcemia [noAnnotations=1]
#  Pulmonary
# ├── COPD
# │   ├── COPD  - moderate [noAnnotations=589]
# │   ├── COPD  - no limitations [noAnnotations=359]
# │   └── COPD  - severe [noAnnotations=204]
# ├── Asthma
# │   └── asthma [noAnnotations=570]
# ├── Home Oxygen
# │   └── home oxygen [noAnnotations=266]
# ├── Restrictive Disease
# │   └── restrictive pulmonary disease [noAnnotations=43]
# ├── Pulmonary Function Tests
# │   ├── FEV1 (%)
# │   │   ├── FEV1 >80 [noAnnotations=40]
# │   │   ├── FEV1 61-70 [noAnnotations=23]
# │   │   ├── FEV1 31-40 [noAnnotations=17]
# │   │   ├── FEV1 <30 [noAnnotations=9]
# │   │   ├── FEV1 51-60 [noAnnotations=3]
# │   │   ├── FEV1 41-50 [noAnnotations=3]
# │   │   └── FEV1 71-80 [noAnnotations=2]
# │   ├── FVC (%)
# │   │   ├── FVC >80 [noAnnotations=39]
# │   │   ├── FVC 31-40 [noAnnotations=17]
# │   │   ├── FVC 61-70 [noAnnotations=3]
# │   │   └── FVC 51-60 [noAnnotations=1]
# │   ├── FEV1
# │   │   └── FVC Ratio
# │   │       └── FEV1
# │   │           ├── FVC ratio >80 [noAnnotations=34]
# │   │           ├── FVC ratio 51-60 [noAnnotations=17]
# │   │           ├── FVC ratio 31-40 [noAnnotations=9]
# │   │           ├── FVC ratio 71-80 [noAnnotations=9]
# │   │           └── FVC ratio 41-50 [noAnnotations=3]
# │   └── DLCO (%)
# │       ├── DLCO 61-70 [noAnnotations=6]
# │       └── DLCO 51-60 [noAnnotations=3]
# ├── Respiratory Failure
# │   ├── respiratory failure - within 6 months [noAnnotations=24]
# │   ├── respiratory failure - date unknown [noAnnotations=10]
# │   ├── respiratory failure - remote [noAnnotations=1]
# │   ├── respiratory failure - within 2 years [noAnnotations=1]
# │   └── respiratory failure - within 5 years [noAnnotations=1]
# ├── Sarcoidosis
# │   └── sarcoidosis [noAnnotations=2]
# └── s
#     └── p Lung Transplant
#         └── s
#             └── p lung transplant [noAnnotations=2]
#  Neurologic
# ├── Strokes
# │   ├── stroke - date unknown [noAnnotations=432]
# │   ├── stroke - within 5 years [noAnnotations=111]
# │   ├── stroke - remote [noAnnotations=94]
# │   ├── stroke - within 6 months [noAnnotations=73]
# │   ├── stroke - within 2 years [noAnnotations=59]
# │   └── multiple
# │       └── multiple [noAnnotations=13]
# ├── Dementia
# │   └── dementia [noAnnotations=254]
# ├── Seizures
# │   ├── generalized seizures [noAnnotations=228]
# │   ├── other seizures [noAnnotations=203]
# │   ├── petite mal seizures [noAnnotations=28]
# │   └── focal seizures [noAnnotations=23]
# ├── TIA(s)
# │   ├── TIA(s) - date unknown [noAnnotations=145]
# │   ├── TIA(s) - within 6 months [noAnnotations=29]
# │   ├── TIA(s) - within 5 years [noAnnotations=17]
# │   ├── TIA(s) - within 2 years [noAnnotations=14]
# │   ├── TIA(s) - remote [noAnnotations=12]
# │   └── multiple
# │       └── multiple [noAnnotations=5]
# ├── Neuromuscular Disease
# │   └── neuromuscular disease [noAnnotations=37]
# └── Intracranial Mass
#     └── intracranial mass [noAnnotations=30]
#  Hematology
# └── Oncology (R)
#     ├── Cancer
#     │   ├── Cancer-Primary Site
#     │   │   ├── lung [noAnnotations=144]
#     │   │   ├── breast [noAnnotations=123]
#     │   │   ├── prostate [noAnnotations=110]
#     │   │   ├── other [noAnnotations=105]
#     │   │   ├── colon [noAnnotations=89]
#     │   │   ├── head and neck [noAnnotations=70]
#     │   │   ├── kidney [noAnnotations=51]
#     │   │   ├── bladder [noAnnotations=43]
#     │   │   ├── melanoma [noAnnotations=39]
#     │   │   ├── esophagus [noAnnotations=39]
#     │   │   ├── uterus [noAnnotations=34]
#     │   │   ├── stomach [noAnnotations=30]
#     │   │   ├── pancreas - adenocarcinoma [noAnnotations=25]
#     │   │   ├── brain [noAnnotations=23]
#     │   │   ├── liver [noAnnotations=21]
#     │   │   ├── ovary [noAnnotations=9]
#     │   │   ├── unknown [noAnnotations=6]
#     │   │   ├── testes [noAnnotations=5]
#     │   │   ├── none [noAnnotations=2]
#     │   │   ├── bone [noAnnotations=1]
#     │   │   ├── bile duct [noAnnotations=1]
#     │   │   └── sarcoma [noAnnotations=1]
#     │   ├── Metastases
#     │   │   ├── bone [noAnnotations=61]
#     │   │   ├── other [noAnnotations=39]
#     │   │   ├── lung [noAnnotations=38]
#     │   │   ├── intra-abdominal [noAnnotations=38]
#     │   │   ├── nodes [noAnnotations=32]
#     │   │   ├── liver [noAnnotations=31]
#     │   │   └── brain [noAnnotations=31]
#     │   └── Hematologic Malignancy
#     │       ├── multiple myeloma [noAnnotations=55]
#     │       ├── non-Hodgkins lymphoma [noAnnotations=34]
#     │       ├── CLL [noAnnotations=26]
#     │       ├── Hodgkins disease [noAnnotations=17]
#     │       ├── other hematologic malignancy [noAnnotations=17]
#     │       ├── AML [noAnnotations=9]
#     │       ├── ALL [noAnnotations=6]
#     │       ├── leukemia - other [noAnnotations=3]
#     │       └── CML [noAnnotations=1]
#     ├── Cancer Therapy
#     │   ├── Chemotherapy
#     │   │   ├── chemotherapy within past mo. [noAnnotations=74]
#     │   │   ├── chemotherapy within past 6 mos. [noAnnotations=61]
#     │   │   ├── Alkylating agents (bleomycin, cytoxan, cyclophos.) [noAnnotations=3]
#     │   │   └── BMT within past 12 mos. [noAnnotations=2]
#     │   └── Radiation Therapy within past 6 months
#     │       ├── primary site [noAnnotations=61]
#     │       ├── lung [noAnnotations=43]
#     │       ├── bone [noAnnotations=21]
#     │       ├── other [noAnnotations=4]
#     │       ├── brain [noAnnotations=4]
#     │       ├── nodes [noAnnotations=3]
#     │       └── liver [noAnnotations=3]
#     ├── ITP
#     │   └── ITP [noAnnotations=40]
#     ├── Hemolytic Anemia
#     │   └── hemolytic anemia [noAnnotations=36]
#     ├── Clotting Disorder
#     │   └── clotting disorder [noAnnotations=17]
#     ├── Hypercoagulable Condition
#     │   └── hypercoagulable condition [noAnnotations=9]
#     ├── Sickle Cell Disease
#     │   └── sickle cell disease [noAnnotations=5]
#     ├── Myeloproliferative Disease
#     │   ├── polycythemia vera [noAnnotations=3]
#     │   ├── essential thrombocytosis [noAnnotations=1]
#     │   └── myelofibrosis [noAnnotations=1]
#     └── Aplastic Anemia
#         └── aplastic anemia [noAnnotations=3]
#  Renal  (R)
# ├── Renal Insufficiency
# │   ├── renal insufficiency - creatinine 1-2 [noAnnotations=384]
# │   ├── renal insufficiency - baseline creatinine unknown [noAnnotations=153]
# │   ├── renal insufficiency - creatinine 2-3 [noAnnotations=133]
# │   ├── renal insufficiency - creatinine 3-4 [noAnnotations=25]
# │   ├── renal insufficiency - creatinine 4-5 [noAnnotations=4]
# │   └── renal insufficiency - creatinine > 5 [noAnnotations=2]
# ├── Renal Failure
# │   ├── renal failure - hemodialysis [noAnnotations=336]
# │   ├── renal failure- not currently dialyzed [noAnnotations=111]
# │   └── renal failure - peritoneal dialysis [noAnnotations=14]
# ├── Chronic Stone Disease
# │   └── chronic kidney stones [noAnnotations=92]
# ├── s
# │   └── p Renal Transplant
# │       └── s
# │           └── p renal transplant [noAnnotations=87]
# └── Neurogenic Bladder
#     └── neurogenic bladder [noAnnotations=9]
#  Gastrointestinal (R)
# ├── Cirrhosis
# │   ├── clinical diagnosis [noAnnotations=250]
# │   ├── varices [noAnnotations=150]
# │   ├── ascites [noAnnotations=149]
# │   ├── encephalopathy [noAnnotations=133]
# │   ├── UGI bleeding [noAnnotations=105]
# │   ├── jaundice [noAnnotations=67]
# │   ├── biopsy proven [noAnnotations=52]
# │   └── coma [noAnnotations=14]
# ├── Peptic Ulcer Disease
# │   ├── peptic ulcer disease [noAnnotations=196]
# │   └── peptic ulcer disease with h
# │       └── o GI bleeding [noAnnotations=37]
# ├── s
# │   └── p Liver Transplant
# │       └── s
# │           └── p liver transplant [noAnnotations=50]
# └── Hypersplenism
#     └── splenomegaly [noAnnotations=29]
#  Rheumatic
# ├── Rheumatoid Arthritis
# │   └── rheumatoid arthritis [noAnnotations=108]
# ├── SLE
# │   └── SLE [noAnnotations=43]
# ├── Dermato
# │   └── Polymyositis
# │       └── dermatomyositis [noAnnotations=13]
# └── Scleroderma
#     └── scleroderma [noAnnotations=1]
#  Infectious Disease (R)
# ├── HIV (only)
# │   └── HIV positive [noAnnotations=77]
# ├── Immunosuppression within past 6 months
# │   ├── other immunosuppressive medications [noAnnotations=45]
# │   ├── both prednisone and other immunosuppressive medications [noAnnotations=15]
# │   └── >= 20 mg prednisone per day or equivalent [noAnnotations=9]
# └── AIDS
#     └── AIDS [noAnnotations=4]

# %%
df1['first'] = df1['first'].str.strip()
from tabulate import tabulate

diseases = ['Cardiovascular (R)', 'Endocrine (R)', 'Pulmonary', 'Neurologic', 'Hematology', 'Renal  (R)', 'Gastrointestinal (R)', 'Rheumatic', 'Infectious Disease (R)']

for disease in diseases:
 
    df_disease = df1[df1['first'] == disease].copy()

    freq = pd.DataFrame()
    freq['noAnnotations'] = df_disease['second'].value_counts()
    freq['%'] = round(df_disease['second'].value_counts() / len(df_disease.index) * 100, 2)

    table = tabulate(freq, headers="keys", tablefmt="psql", showindex=True)
    print(f"The frequency of {disease}:")
    print(table)
    print("------------------------------")
# Out:
# The frequency of Cardiovascular (R):
# +----------------------------------+-----------------+-------+
# | second                           |   noAnnotations |     % |
# |----------------------------------+-----------------+-------|
# | Hypertension Requiring Treatment |            4771 | 38.66 |
# | Congestive Heart Failure         |            1341 | 10.87 |
# | Arrhythmias                      |            1241 | 10.06 |
# | Valve disease                    |             908 |  7.36 |
# | Myocardial Infarction            |             894 |  7.24 |
# | Procedural Coronary Intervention |             739 |  5.99 |
# | Coronary Artery Bypass           |             580 |  4.7  |
# | Peripheral Vascular Disease      |             540 |  4.38 |
# | Pacemaker                        |             336 |  2.72 |
# | Venous Thrombosis                |             278 |  2.25 |
# | Angina                           |             215 |  1.74 |
# | AICD                             |             203 |  1.64 |
# | Pulmonary Embolism               |             179 |  1.45 |
# | Exercise Tolerance               |              76 |  0.62 |
# | s                                |              40 |  0.32 |
# +----------------------------------+-----------------+-------+
# ------------------------------
# The frequency of Endocrine (R):
# +------------------------------------+-----------------+-------+
# | second                             |   noAnnotations |     % |
# |------------------------------------+-----------------+-------|
# | Non-Insulin Dependent Diabetes     |            1325 | 40.67 |
# | Insulin Dependent Diabetes         |            1010 | 31    |
# | Hypothyroidism                     |             821 | 25.2  |
# | Hyperthyroidism                    |              48 |  1.47 |
# | Recent Steroid Use (for > 10 days) |              48 |  1.47 |
# | Cushing's Syndrome                 |               5 |  0.15 |
# | Hypercalcemia                      |               1 |  0.03 |
# +------------------------------------+-----------------+-------+
# ------------------------------
# The frequency of Pulmonary:
# +--------------------------+-----------------+-------+
# | second                   |   noAnnotations |     % |
# |--------------------------+-----------------+-------|
# | COPD                     |            1152 | 49.87 |
# | Asthma                   |             570 | 24.68 |
# | Home Oxygen              |             266 | 11.52 |
# | Pulmonary Function Tests |             238 | 10.3  |
# | Restrictive Disease      |              43 |  1.86 |
# | Respiratory Failure      |              37 |  1.6  |
# | Sarcoidosis              |               2 |  0.09 |
# | s                        |               2 |  0.09 |
# +--------------------------+-----------------+-------+
# ------------------------------
# The frequency of Neurologic:
# +-----------------------+-----------------+-------+
# | second                |   noAnnotations |     % |
# |-----------------------+-----------------+-------|
# | Strokes               |             782 | 43.28 |
# | Seizures              |             482 | 26.67 |
# | Dementia              |             254 | 14.06 |
# | TIA(s)                |             222 | 12.29 |
# | Neuromuscular Disease |              37 |  2.05 |
# | Intracranial Mass     |              30 |  1.66 |
# +-----------------------+-----------------+-------+
# ------------------------------
# The frequency of Hematology:
# +--------------+-----------------+-----+
# | second       |   noAnnotations |   % |
# |--------------+-----------------+-----|
# | Oncology (R) |            1803 | 100 |
# +--------------+-----------------+-----+
# ------------------------------
# The frequency of Renal  (R):
# +-----------------------+-----------------+-------+
# | second                |   noAnnotations |     % |
# |-----------------------+-----------------+-------|
# | Renal Insufficiency   |             701 | 51.93 |
# | Renal Failure         |             461 | 34.15 |
# | Chronic Stone Disease |              92 |  6.81 |
# | s                     |              87 |  6.44 |
# | Neurogenic Bladder    |               9 |  0.67 |
# +-----------------------+-----------------+-------+
# ------------------------------
# The frequency of Gastrointestinal (R):
# +----------------------+-----------------+-------+
# | second               |   noAnnotations |     % |
# |----------------------+-----------------+-------|
# | Cirrhosis            |             920 | 74.68 |
# | Peptic Ulcer Disease |             233 | 18.91 |
# | s                    |              50 |  4.06 |
# | Hypersplenism        |              29 |  2.35 |
# +----------------------+-----------------+-------+
# ------------------------------
# The frequency of Rheumatic:
# +----------------------+-----------------+-------+
# | second               |   noAnnotations |     % |
# |----------------------+-----------------+-------|
# | Rheumatoid Arthritis |             108 | 65.45 |
# | SLE                  |              43 | 26.06 |
# | Dermato              |              13 |  7.88 |
# | Scleroderma          |               1 |  0.61 |
# +----------------------+-----------------+-------+
# ------------------------------
# The frequency of Infectious Disease (R):
# +----------------------------------------+-----------------+-------+
# | second                                 |   noAnnotations |     % |
# |----------------------------------------+-----------------+-------|
# | HIV (only)                             |              77 | 51.33 |
# | Immunosuppression within past 6 months |              69 | 46    |
# | AIDS                                   |               4 |  2.67 |
# +----------------------------------------+-----------------+-------+
# ------------------------------

# %%
df1['diagnosisstring'] = df1['diagnosisstring'].str.split('/').str[:2].str.join('/')
df1 = df1.drop(columns=['third','fourth'])
df1
# Out:
#         patient                                    diagnosisstring  \
# 23819    260132                       Endocrine (R)/Hypothyroidism
# 24064    261021                       Cardiovascular (R)/Pacemaker
# 24065    261021                                   Pulmonary/Asthma
# 24066    261021                                     Pulmonary/COPD
# 24067    261021                                   Pulmonary/Asthma
# ...         ...                                                ...
# 471271  3247116                      Pulmonary/Respiratory Failure
# 471272  3247116   Cardiovascular (R)/Hypertension Requiring Tre...
# 471273  3247116                              Pulmonary/Home Oxygen
# 471274  3247116                                     Pulmonary/COPD
# 471275  3247116                     Cardiovascular (R)/Arrhythmias
#
#                      first                            second
# 23819        Endocrine (R)                    Hypothyroidism
# 24064   Cardiovascular (R)                         Pacemaker
# 24065            Pulmonary                            Asthma
# 24066            Pulmonary                              COPD
# 24067            Pulmonary                            Asthma
# ...                    ...                               ...
# 471271           Pulmonary               Respiratory Failure
# 471272  Cardiovascular (R)  Hypertension Requiring Treatment
# 471273           Pulmonary                       Home Oxygen
# 471274           Pulmonary                              COPD
# 471275  Cardiovascular (R)                       Arrhythmias
#
# [24416 rows x 4 columns]

# %%
csv= '/home/mei/nas/docker/thesis/data/csv/'
df1.to_csv(csv+'diagnoses_trim.csv')

hdf= '/home/mei/nas/docker/thesis/data/hdf/'
df1.to_hdf(hdf+'final_diagnoses_trim.h5', key='df')

# %%
df1
# Out:
#         patient                                    diagnosisstring  \
# 23819    260132                       Endocrine (R)/Hypothyroidism
# 24064    261021                       Cardiovascular (R)/Pacemaker
# 24065    261021                                   Pulmonary/Asthma
# 24066    261021                                     Pulmonary/COPD
# 24067    261021                                   Pulmonary/Asthma
# ...         ...                                                ...
# 471271  3247116                      Pulmonary/Respiratory Failure
# 471272  3247116   Cardiovascular (R)/Hypertension Requiring Tre...
# 471273  3247116                              Pulmonary/Home Oxygen
# 471274  3247116                                     Pulmonary/COPD
# 471275  3247116                     Cardiovascular (R)/Arrhythmias
#
#                      first                            second
# 23819        Endocrine (R)                    Hypothyroidism
# 24064   Cardiovascular (R)                         Pacemaker
# 24065            Pulmonary                            Asthma
# 24066            Pulmonary                              COPD
# 24067            Pulmonary                            Asthma
# ...                    ...                               ...
# 471271           Pulmonary               Respiratory Failure
# 471272  Cardiovascular (R)  Hypertension Requiring Treatment
# 471273           Pulmonary                       Home Oxygen
# 471274           Pulmonary                              COPD
# 471275  Cardiovascular (R)                       Arrhythmias
#
# [24416 rows x 4 columns]
