# %%
import pandas as pd
import os
from utils import *

# %%
hdf= '/home/mei/nas/docker/thesis/data/hdf/'

flat_features = pd.read_hdf(os.path.join(hdf, 'final_flat_drug.h5')).set_index('patient')
diagnoses = pd.read_hdf(os.path.join(hdf, 'final_diagnoses_trim.h5')).set_index('patient')
timeseries = pd.read_hdf(os.path.join(hdf, 'final_timeseries.h5')).reset_index().set_index('patient')
risks = pd.read_hdf(os.path.join(hdf, 'final_risk_scores.h5')).set_index('patient')

# %%
split_train_test(hdf,flat_features, diagnoses,timeseries,risks)
# Out:
# ==> Loading data for splitting...
# ==> Preparing train data...
# ==> train data saved!
#
# ==> Preparing val data...
# ==> val data saved!
#
# ==> Preparing test data...
# ==> test data saved!
#
#
# ==== Dataset Sizes ====
# **train set:**
# - Flat Features: (2150, 104)
# - Diagnoses: (2150, 39)
# - Time Series: (3126284, 155)
# - Labels: (3126284, 8)
#
# **val set:**
# - Flat Features: (461, 104)
# - Diagnoses: (461, 39)
# - Time Series: (692647, 155)
# - Labels: (692647, 8)
#
# **test set:**
# - Flat Features: (461, 104)
# - Diagnoses: (461, 39)
# - Time Series: (667500, 155)
# - Labels: (667500, 8)
#
# ==> Splitting complete!

# %%
import h5py

def save_to_h5py(data_path,partition,risk=False):
    partition_path = os.path.join(data_path, partition)
    if risk: 
       timeseries_file = os.path.join(partition_path, 'risks.h5')
       timeseries_data = pd.read_hdf(timeseries_file)
       output_file = os.path.join(partition_path, 'risk_each_patient.h5')
    else:
        timeseries_file = os.path.join(partition_path, 'timeseries.h5')
        timeseries_data = pd.read_hdf(timeseries_file)
        output_file = os.path.join(partition_path, 'ts_each_patient.h5')
  
    with h5py.File(output_file, 'w') as h5f:
        for patient_id, group in timeseries_data.groupby('patient'):
            h5f.create_dataset(str(patient_id), data=group.values)
    
    print(f'Data for {partition} saved successfully in h5py version!')

# %%
hdf= '/home/mei/nas/docker/thesis/data/hdf/'

for partition in ['train', 'val', 'test']:
    save_to_h5py(hdf,partition,risk=False)
    save_to_h5py(hdf,partition,risk=True)
# Out:
# Data for train1 saved successfully in h5py version!
# Data for train1 saved successfully in h5py version!
# Data for val saved successfully in h5py version!
# Data for val saved successfully in h5py version!
# Data for test saved successfully in h5py version!
# Data for test saved successfully in h5py version!

# %%
risks
# Out:
#          time  gender   age  dischargeweight  unitdischargestatus  \
# patient
# 260132      1       0  89.0             84.1                    1
# 260132      2       0  89.0             84.1                    1
# 260132      3       0  89.0             84.1                    1
# 260132      4       0  89.0             84.1                    1
# 260132      5       0  89.0             84.1                    1
# ...       ...     ...   ...              ...                  ...
# 3247116  2328       0  52.0             68.0                    1
# 3247116  2329       0  52.0             68.0                    1
# 3247116  2330       0  52.0             68.0                    1
# 3247116  2331       0  52.0             68.0                    1
# 3247116  2332       0  52.0             68.0                    1
#
#          discharge_risk_category  actualiculos  risk_score
# patient
# 260132                         3        0.1819    0.989578
# 260132                         3        0.1819    0.989812
# 260132                         3        0.1819    0.990046
# 260132                         3        0.1819    0.990280
risk_test = pd.read_hdf(os.path.join(hdf, 'test/risks.h5'))
risk_test
# Out:
#          time  gender   age  dischargeweight  unitdischargestatus  \
# patient
# 320647      1       1  61.0             84.1                    0
# 320647      2       1  61.0             84.1                    0
# 320647      3       1  61.0             84.1                    0
# 320647      4       1  61.0             84.1                    0
# 320647      5       1  61.0             84.1                    0
# ...       ...     ...   ...              ...                  ...
# 3244909   828       1  63.0             83.9                    0
# 3244909   829       1  63.0             83.9                    0
# 3244909   830       1  63.0             83.9                    0
# 3244909   831       1  63.0             83.9                    0
# 3244909   832       1  63.0             83.9                    0
#
#          discharge_risk_category  actualiculos  risk_score
# patient
# 320647                         2        5.1069    0.483171
# 320647                         2        5.1069    0.483134
# 320647                         2        5.1069    0.483098
# 320647                         2        5.1069    0.483061
# 320647                         2        5.1069    0.483024
# ...                          ...           ...         ...
# 3244909                        1        1.9756    0.200450
# 3244909                        1        1.9756    0.200337
# 3244909                        1        1.9756    0.200225
# 3244909                        1        1.9756    0.200112
# 3244909                        1        1.9756    0.200000
#
# [667500 rows x 8 columns]

# %%
flat_test = pd.read_hdf(os.path.join(hdf, 'test/flat.h5'))
flat_test
# Out:
#          gender   age  admissionweight  larger_than_89  acetaminophen  \
# patient
# 320647        1  61.0            108.0               0              0
# 426638        1  51.0            108.8               0              0
# 430027        0  89.0             75.2               1              0
# 445889        0  60.0             83.6               0              0
# 446339        1  77.0             90.2               0              0
# ...         ...   ...              ...             ...            ...
# 3237396       1  60.0             93.1               0              0
# 3239059       0  76.0            113.4               0              0
# 3240660       0  56.0             70.2               0              0
# 3240896       0  69.0            100.8               0              0
# 3244909       1  63.0             82.6               0              1
#
#          advair_diskus  albuterol  albuterol_sulfate  allopurinol  alprazolam  \
# patient
# 320647               0          0                  0            0           0
# 426638               0          0                  0            0           0
# 430027               1          0                  1            0           0
# 445889               0          0                  0            0           0
# 446339               0          0                  0            0           0
# ...                ...        ...                ...          ...         ...
# 3237396              0          0                  0            0           1
# 3239059              0          1                  0            0           0
# 3240660              0          0                  0            0           0
# 3240896              0          1                  0            0           0
# 3244909              0          0                  0            0           0
#
#          ...  tramadol_hcl  trazodone_hcl  tylenol  vancomycin  ventolin_hfa  \
# patient  ...
# 320647   ...             0              0        0           0             0
# 426638   ...             0              0        0           0             0
# 430027   ...             0              0        0           0             0
# 445889   ...             0              0        0           0             0
# 446339   ...             0              0        0           0             0
# ...      ...           ...            ...      ...         ...           ...
# 3237396  ...             0              0        0           0             0
# 3239059  ...             0              0        0           0             0
# 3240660  ...             0              0        0           0             0
# 3240896  ...             0              0        0           0             0
# 3244909  ...             0              0        0           0             0
#
#          vicodin  vitamin_c  vitamin_d  warfarin_sodium  zofran
# patient
# 320647         0          0          0                0       0
# 426638         0          0          0                0       0
# 430027         0          0          0                0       0
# 445889         0          0          0                0       0
# 446339         0          0          0                0       0
# ...          ...        ...        ...              ...     ...
# 3237396        0          0          0                0       0
# 3239059        0          0          0                0       0
# 3240660        0          0          0                0       0
# 3240896        0          0          1                0       0
# 3244909        0          0          0                0       0
#
# [461 rows x 104 columns]

# %%
diagnoses_test = pd.read_hdf(os.path.join(hdf, 'test/diagnoses.h5'))
diagnoses_test
# Out:
#          Cardiovascular (R)  Cardiovascular (R)|AICD  \
# patient
# 320647                    1                        0
# 426638                    1                        0
# 430027                    1                        0
# 445889                    1                        0
# 446339                    1                        0
# ...                     ...                      ...
# 3237396                   1                        0
# 3239059                   1                        0
# 3240660                   1                        0
# 3240896                   1                        0
# 3244909                   1                        0
#
#          Cardiovascular (R)|Angina  Cardiovascular (R)|Arrhythmias  \
# patient
# 320647                           0                               0
# 426638                           0                               1
# 430027                           0                               1
# 445889                           0                               0
# 446339                           0                               0
# ...                            ...                             ...
# 3237396                          0                               1
# 3239059                          0                               0
# 3240660                          0                               0
# 3240896                          0                               0
# 3244909                          0                               0
#
#          Cardiovascular (R)|Congestive Heart Failure  \
# patient
# 320647                                             1
# 426638                                             0
# 430027                                             1
# 445889                                             0
# 446339                                             0
# ...                                              ...
# 3237396                                            0
# 3239059                                            0
# 3240660                                            0
# 3240896                                            0
# 3244909                                            0
#
#          Cardiovascular (R)|Coronary Artery Bypass  \
# patient
# 320647                                           0
# 426638                                           0
# 430027                                           0
# 445889                                           0
# 446339                                           0
# ...                                            ...
# 3237396                                          0
# 3239059                                          0
# 3240660                                          0
# 3240896                                          0
# 3244909                                          0
#
#          Cardiovascular (R)|Hypertension Requiring Treatment  \
# patient
# 320647                                                   0
# 426638                                                   1
# 430027                                                   1
# 445889                                                   1
# 446339                                                   1
# ...                                                    ...
# 3237396                                                  0
# 3239059                                                  1
# 3240660                                                  1
# 3240896                                                  1
# 3244909                                                  1
#
#          Cardiovascular (R)|Myocardial Infarction  \
# patient
# 320647                                          1
# 426638                                          1
# 430027                                          0
# 445889                                          0
# 446339                                          0
# ...                                           ...
# 3237396                                         0
# 3239059                                         0
# 3240660                                         0
# 3240896                                         0
# 3244909                                         0
#
#          Cardiovascular (R)|Pacemaker  \
# patient
# 320647                              0
# 426638                              0
# 430027                              0
# 445889                              0
# 446339                              0
# ...                               ...
# 3237396                             0
# 3239059                             0
# 3240660                             0
# 3240896                             0
# 3244909                             0
#
#          Cardiovascular (R)|Peripheral Vascular Disease  ...  Pulmonary  \
# patient                                                  ...
# 320647                                                0  ...          0
# 426638                                                0  ...          0
# 430027                                                0  ...          1
# 445889                                                0  ...          0
# 446339                                                0  ...          0
# ...                                                 ...  ...        ...
# 3237396                                               0  ...          0
# 3239059                                               0  ...          0
# 3240660                                               0  ...          0
# 3240896                                               0  ...          0
# 3244909                                               0  ...          0
#
#          Pulmonary|Asthma  Pulmonary|COPD  Pulmonary|Home Oxygen  Renal  (R)  \
# patient
# 320647                  0               0                      0           0
# 426638                  0               0                      0           0
# 430027                  1               1                      1           0
# 445889                  0               0                      0           0
# 446339                  0               0                      0           0
# ...                   ...             ...                    ...         ...
# 3237396                 0               0                      0           0
# 3239059                 0               0                      0           0
# 3240660                 0               0                      0           0
# 3240896                 0               0                      0           0
# 3244909                 0               0                      0           0
#
#          Renal  (R)|Chronic Stone Disease  Renal  (R)|Renal Failure  \
# patient
# 320647                                  0                         0
# 426638                                  0                         0
# 430027                                  0                         0
# 445889                                  0                         0
# 446339                                  0                         0
# ...                                   ...                       ...
# 3237396                                 0                         0
# 3239059                                 0                         0
# 3240660                                 0                         0
# 3240896                                 0                         0
# 3244909                                 0                         0
#
#          Renal  (R)|Renal Insufficiency  Rheumatic  \
# patient
# 320647                                0          0
# 426638                                0          0
# 430027                                0          0
# 445889                                0          0
# 446339                                0          0
# ...                                 ...        ...
# 3237396                               0          0
# 3239059                               0          0
# 3240660                               0          0
# 3240896                               0          0
# 3244909                               0          0
#
#          Rheumatic|Rheumatoid Arthritis
# patient
# 320647                                0
# 426638                                0
# 430027                                0
# 445889                                0
# 446339                                0
# ...                                 ...
# 3237396                               0
# 3239059                               0
# 3240660                               0
# 3240896                               0
# 3244909                               0
#
# [461 rows x 39 columns]

# %%
import h5py
hdf= '/home/mei/nas/docker/thesis/data/hdf/'

risks_each_patient_test = h5py.File(os.path.join(hdf, 'test/risk_each_patient.h5'), 'r')
risk_train  = h5py.File(os.path.join(hdf, 'train/risk_each_patient.h5'), 'r')
risk_val = h5py.File(os.path.join(hdf, 'val/risk_each_patient.h5'), 'r')
risk_test = h5py.File(os.path.join(hdf, 'test/risk_each_patient.h5'), 'r')

# %%
import pandas as pd

def read_h5_file_to_df(h5_file, columns):
    all_data = []
    for pid in h5_file.keys():
        data = h5_file[pid][:]
        df = pd.DataFrame(data, columns=columns)
        df["patient"] = int(pid)
        all_data.append(df)
    return pd.concat(all_data, ignore_index=True)

# %%
def summarize_by_risk(df, name=""):
    grouped = df.groupby("discharge_risk_category")
    summary = grouped.agg(
        patient_count=("patient", lambda x: x.nunique()),
        record_count=("patient", "count")
    ).sort_index()

    print(f"\ Summary for {name.upper()}:")
    print(summary)
    return summary

# %%
COLUMNS = ['time', 'gender', 'age', 'dischargeweight', 'unitdischargestatus',
           'discharge_risk_category', 'actualiculos', 'risk_score']

# %%
df_train = read_h5_file_to_df(risk_train, COLUMNS)
df_val = read_h5_file_to_df(risk_val, COLUMNS)
df_test = read_h5_file_to_df(risk_test, COLUMNS)

summarize_by_risk(df_train, "train")
summarize_by_risk(df_val, "val")
summarize_by_risk(df_test, "test")
# Out:
# \ Summary for TRAIN:
#                          patient_count  record_count
# discharge_risk_category
# 0.0                                166         81986
# 1.0                               1303       2227418
# 2.0                                356        552741
# 3.0                                325        264139
# \ Summary for VAL:
#                          patient_count  record_count
# discharge_risk_category
# 0.0                                 37         18841
# 1.0                                280        479214
# 2.0                                 87        138928
# 3.0                                 57         55664
# \ Summary for TEST:
#                          patient_count  record_count
# discharge_risk_category
# 0.0                                 27         12505
# 1.0                                294        477276
# 2.0                                 89        135537
# 3.0                                 51         42182
#                          patient_count  record_count
# discharge_risk_category
# 0.0                                 27         12505
# 1.0                                294        477276
# 2.0                                 89        135537
# 3.0                                 51         42182
